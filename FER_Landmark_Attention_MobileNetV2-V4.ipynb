# %% [markdown]
# # Started from here!

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models

import cv2
import numpy as np
from PIL import Image
import os

import heapq
import itertools
from sklearn.decomposition import PCA

# %%
test_dir = 'data/merged/test/'
train_dir = 'data/merged/train/'

#b_train_dir = 'data/balanced/'

classes = os.listdir(train_dir)
test_cls = os.listdir(train_dir)
num_classes = len(classes)

# %%
print(
    f'Number of classes: {num_classes}',
    f'\nClasses: {classes}'
)
# Out:
# Number of classes: 7
# Classes: ['fear', 'angry', 'sad', 'neutral', 'surprise', 'disgust', 'happy']

# %%
print("--------Train--------")
# check the number of images in each class
for cls in classes:
    print(f'{cls}: {len(os.listdir(train_dir + cls))}')

print("\n--------Test--------")
# check the number of images in each class
for cls in classes:
    print(f'{cls}: {len(os.listdir(test_dir + cls))}')
    
#print("\n--------balance--------")
## check the number of images in each class
#for cls in classes:
#    print(f'{cls}: {len(os.listdir(b_train_dir + cls))}')
# Out:
# --------Train--------
# fear: 5000
# angry: 5000
# sad: 5000
# neutral: 5000
# surprise: 5000
# disgust: 5000
# happy: 7215
#
# --------Test--------
# fear: 1024
# angry: 1000
# sad: 1247
# neutral: 1233
# surprise: 1000
# disgust: 1000
# happy: 1774

# %%
import os
import imghdr
import shutil

def delete_irrelevant_files(directory, classes):
    for cls in classes:
        class_dir = os.path.join(directory, cls)
        with os.scandir(class_dir) as entries:
            for entry in entries:
                # Delete directories
                if entry.is_dir():
                    print(f'Deleting directory: {entry.path}')
                    shutil.rmtree(entry.path)

                # Check if the file is empty and delete it
                elif os.path.getsize(entry.path) == 0:
                    print(f'Deleting empty file: {entry.path}')
                    os.remove(entry.path)

                # Check if the file is not an image and delete it
                elif not imghdr.what(entry.path):
                    print(f'Deleting non-image file: {entry.path}')
                    os.remove(entry.path)

print("--------Train--------")
delete_irrelevant_files(train_dir, classes)

print("\n--------Test--------")
delete_irrelevant_files(test_dir, classes)

#delete_irrelevant_files(b_train_dir, classes)
# Out:
# --------Train--------
#
# --------Test--------

# %% [markdown]
# # Landmark detection from images and correlation of those landmark positions

# %%
image_size = torch.Size([48, 48, 3])
batch_size = 256

# Compute the total size of the image input
image_input_size = np.prod(image_size) * batch_size * 4. / (1024 ** 2.)
print(f"Image input size: {image_input_size:.2f} MB")
# Out:
# Image input size: 6.75 MB

# %%
class FER_Dataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.data = []
        self.labels = []  # new list to store the label index
        for i, label in enumerate(os.listdir(root_dir)):
            class_dir = os.path.join(root_dir, label)
            for img_name in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_name)
                image = cv2.imread(img_path)
                self.data.append(image)
                self.labels.append(i)  # add the label index for this image

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image = self.data[idx]
        label = self.labels[idx]  # get the label index for this image

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)

        if self.transform:
            image = self.transform(image)

        return image, label  # return the image and label index

# %%
# Train the model
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = FER_Dataset(train_dir, transform=transform)
val_dataset = FER_Dataset(test_dir, transform=transform)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=256, shuffle=True, num_workers=24)
val_dataloader = DataLoader(val_dataset, batch_size=256, shuffle=False, num_workers=24)

# %%
# show shape of the train_dataloader
for i, data in enumerate(train_dataloader):
    print(i, data[0].shape, data[1].shape)
    break

# show shape of the val_dataloader
for i, data in enumerate(val_dataloader):
    print(i, data[0].shape, data[1].shape)
    break

# torch.Size([4, 3, 48, 48]) torch.Size([4])
# torch.Size([4, 3, 48, 48]) torch.Size([4])

# 0 torch.Size([256, 3, 64, 64]) torch.Size([256])
# 0 torch.Size([256, 3, 64, 64]) torch.Size([256])
# Out:
# 0 torch.Size([256, 3, 128, 128]) torch.Size([256])
# 0 torch.Size([256, 3, 128, 128]) torch.Size([256])

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, input_dim, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.input_dim = input_dim
        self.num_heads = num_heads
        self.head_dim = input_dim // num_heads

        self.query = nn.Linear(input_dim, input_dim)
        self.key = nn.Linear(input_dim, input_dim)
        self.value = nn.Linear(input_dim, input_dim)

        self.fc = nn.Linear(input_dim, input_dim)

    def scaled_dot_product_attention(self, query, key, value):
        qk = torch.matmul(query, key.transpose(-2, -1))
        dk = query.size(-1)
        scaled_attention_logits = qk / torch.sqrt(torch.tensor(dk, dtype=torch.float32, device=qk.device))

        attention_weights = F.softmax(scaled_attention_logits, dim=-1)
        output = torch.matmul(attention_weights, value)
        return output, attention_weights

    def split_heads(self, x):
        batch_size = x.size(0)
        x = x.view(batch_size, -1, self.num_heads, self.head_dim)
        return x.transpose(1, 2)

    def forward(self, x):
        batch_size = x.size(0)

        query = self.query(x)
        key = self.key(x)
        value = self.value(x)

        query = self.split_heads(query)
        key = self.split_heads(key)
        value = self.split_heads(value)

        out, attention_weights = self.scaled_dot_product_attention(query, key, value)
        out = out.transpose(1, 2).contiguous().view(batch_size, -1, self.input_dim)

        out = self.fc(out)
        
        return out

# %%
class FacialExpressionDetectionModel(nn.Module):
    def __init__(self, num_classes, num_heads):
        super(FacialExpressionDetectionModel, self).__init__()
        
        # Load pre-trained MobileNetV2 model
        mobilenet_v2 = models.mobilenet_v2(weights=True)
        mobilenet_features = mobilenet_v2.features

        # Freeze the first three blocks of the MobileNetV2 model
        for param in mobilenet_features[:18].parameters():
            param.requires_grad = False

        self.conv1 = nn.Sequential(
            # remaining layers of the mobilenetV2
            mobilenet_features[0],
            mobilenet_features[1],
            mobilenet_features[2],
            # Biases are freezed just like in the François Chollet's Book!
            nn.Conv2d(24, 64, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 128, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5)
        )

        # Block-2
        self.conv2 = nn.Sequential(
            nn.Conv2d(128, 512, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(512),
            nn.Conv2d(512, 256, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5)
        )

        # Block-3
        self.conv3 = nn.Sequential(
            nn.Conv2d(256, 128, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.Conv2d(128, 128, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.25)
        )

        # Block-4
        self.conv4 = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 256, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.125)
        )

        # Block-5
        self.fc1 = nn.Sequential(
            nn.Linear(64 * 4 * 4, 512),  # Update the input size to match the new input shape
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(512),
            nn.Dropout(0.25)
        )

        # Attention Layer
        self.attention = MultiHeadAttention(512, num_heads)
        self.attention_transform = nn.Linear(512, 64)


        # Block-6
        self.fc2 = nn.Sequential(
            nn.Linear(64, 32),  # Update the input size to 64
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(32),
            nn.Dropout(0.125),
        )

        # Block-7
        self.fc3 = nn.Linear(32, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.attention(x)
        x = x.view(x.size(0), -1)  # Flatten the output of the attention layer
        x = self.attention_transform(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return F.softmax(x, dim=1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_classes = 7
num_heads = 32
model = FacialExpressionDetectionModel(num_classes, num_heads).to(device)
# Out:
# /usr/lib/python3/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
with open('FER_model.txt', 'w') as f:
    f.write(str(model))

# %%
def train_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    running_corrects = 0

    for data, targets in dataloader:
        data = data.to(device)
        targets = targets.to(device)

        # Use autocast for mixed precision
        with autocast():
            outputs = model(data)
            loss = criterion(outputs, targets)
            _, preds = torch.max(outputs, 1)

        # Scale the loss and perform backpropagation
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() * data.size(0)
        running_corrects += torch.sum(preds == targets.data)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

# %%
def validate_epoch(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for data, targets in dataloader:
            data, targets = data.to(device), targets.to(device)

            # Use autocast for mixed precision
            with autocast():
                outputs = model(data)
                loss = criterion(outputs, targets)
                _, preds = torch.max(outputs, 1)

            running_loss += loss.item() * data.size(0)
            running_corrects += torch.sum(preds == targets.data)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

# %%
import torch.optim as optim
from torch.cuda.amp import GradScaler, autocast
from torch.optim.lr_scheduler import ReduceLROnPlateau

model = FacialExpressionDetectionModel(num_classes, num_heads).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, threshold=0.0001)
scaler = GradScaler()

# %%
print(device)
# Out:
# cuda

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
import matplotlib.pyplot as plt

# create empty lists to store loss and accuracy for each epoch
train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

num_epochs = 200
for epoch in range(num_epochs):
    
    train_loss, train_acc = train_epoch(model, train_dataloader, criterion, optimizer, device)
    val_loss, val_acc = validate_epoch(model, val_dataloader, criterion, device)
    scheduler.step(val_loss)
    
    # append the loss and accuracy to the lists
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)


    print(f"Epoch: {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
# Out:
# Epoch: 1/200, Train Loss: 1.7559, Train Acc: 0.4085, Val Loss: 1.6544, Val Acc: 0.5058
# Epoch: 2/200, Train Loss: 1.6696, Train Acc: 0.4945, Val Loss: 1.6299, Val Acc: 0.5310
# Epoch: 3/200, Train Loss: 1.6463, Train Acc: 0.5160, Val Loss: 1.6274, Val Acc: 0.5342
# Epoch: 4/200, Train Loss: 1.6296, Train Acc: 0.5321, Val Loss: 1.6289, Val Acc: 0.5323
# Epoch: 5/200, Train Loss: 1.6171, Train Acc: 0.5452, Val Loss: 1.5864, Val Acc: 0.5738
# Epoch: 6/200, Train Loss: 1.6064, Train Acc: 0.5563, Val Loss: 1.6045, Val Acc: 0.5565
# Epoch: 7/200, Train Loss: 1.6076, Train Acc: 0.5529, Val Loss: 1.5788, Val Acc: 0.5821
# Epoch: 8/200, Train Loss: 1.5890, Train Acc: 0.5730, Val Loss: 1.5798, Val Acc: 0.5805
# Epoch: 9/200, Train Loss: 1.5863, Train Acc: 0.5766, Val Loss: 1.5603, Val Acc: 0.6009
# Epoch: 10/200, Train Loss: 1.5773, Train Acc: 0.5852, Val Loss: 1.5478, Val Acc: 0.6131
# Epoch: 11/200, Train Loss: 1.5718, Train Acc: 0.5904, Val Loss: 1.5427, Val Acc: 0.6179
# Epoch: 12/200, Train Loss: 1.5655, Train Acc: 0.5966, Val Loss: 1.5577, Val Acc: 0.6038
# Epoch: 13/200, Train Loss: 1.5614, Train Acc: 0.6013, Val Loss: 1.5648, Val Acc: 0.5981
# Epoch: 14/200, Train Loss: 1.5629, Train Acc: 0.5995, Val Loss: 1.5402, Val Acc: 0.6221
# Epoch: 15/200, Train Loss: 1.5555, Train Acc: 0.6069, Val Loss: 1.5453, Val Acc: 0.6151
# Epoch: 16/200, Train Loss: 1.5484, Train Acc: 0.6149, Val Loss: 1.5382, Val Acc: 0.6245
# Epoch: 17/200, Train Loss: 1.5453, Train Acc: 0.6175, Val Loss: 1.5268, Val Acc: 0.6354
# Epoch: 18/200, Train Loss: 1.5459, Train Acc: 0.6163, Val Loss: 1.5366, Val Acc: 0.6252
# Epoch: 19/200, Train Loss: 1.5387, Train Acc: 0.6236, Val Loss: 1.5478, Val Acc: 0.6145
# Epoch: 20/200, Train Loss: 1.5367, Train Acc: 0.6264, Val Loss: 1.5245, Val Acc: 0.6372
# Epoch: 21/200, Train Loss: 1.5360, Train Acc: 0.6270, Val Loss: 1.5376, Val Acc: 0.6225
# Epoch: 22/200, Train Loss: 1.5321, Train Acc: 0.6313, Val Loss: 1.5264, Val Acc: 0.6357
# Epoch: 23/200, Train Loss: 1.5313, Train Acc: 0.6311, Val Loss: 1.5273, Val Acc: 0.6351
# Epoch: 24/200, Train Loss: 1.5242, Train Acc: 0.6396, Val Loss: 1.5286, Val Acc: 0.6330
# Epoch: 25/200, Train Loss: 1.5275, Train Acc: 0.6361, Val Loss: 1.5532, Val Acc: 0.6080
# Epoch: 26/200, Train Loss: 1.5270, Train Acc: 0.6358, Val Loss: 1.5376, Val Acc: 0.6254
# Epoch: 27/200, Train Loss: 1.5058, Train Acc: 0.6572, Val Loss: 1.5065, Val Acc: 0.6573
# Epoch: 28/200, Train Loss: 1.4914, Train Acc: 0.6721, Val Loss: 1.4995, Val Acc: 0.6626
# Epoch: 29/200, Train Loss: 1.4843, Train Acc: 0.6800, Val Loss: 1.4981, Val Acc: 0.6668
# Epoch: 30/200, Train Loss: 1.4779, Train Acc: 0.6864, Val Loss: 1.4972, Val Acc: 0.6665
# Epoch: 31/200, Train Loss: 1.4746, Train Acc: 0.6896, Val Loss: 1.4952, Val Acc: 0.6684
# Epoch: 32/200, Train Loss: 1.4709, Train Acc: 0.6931, Val Loss: 1.4927, Val Acc: 0.6690
# Epoch: 33/200, Train Loss: 1.4687, Train Acc: 0.6942, Val Loss: 1.4919, Val Acc: 0.6708
# Epoch: 34/200, Train Loss: 1.4661, Train Acc: 0.6980, Val Loss: 1.4916, Val Acc: 0.6718
# Epoch: 35/200, Train Loss: 1.4636, Train Acc: 0.7001, Val Loss: 1.4906, Val Acc: 0.6721
# Epoch: 36/200, Train Loss: 1.4589, Train Acc: 0.7053, Val Loss: 1.4912, Val Acc: 0.6726
# Epoch: 37/200, Train Loss: 1.4580, Train Acc: 0.7071, Val Loss: 1.4934, Val Acc: 0.6695
# Epoch: 38/200, Train Loss: 1.4550, Train Acc: 0.7097, Val Loss: 1.4917, Val Acc: 0.6707
# Epoch: 39/200, Train Loss: 1.4542, Train Acc: 0.7105, Val Loss: 1.4912, Val Acc: 0.6711
# Epoch: 40/200, Train Loss: 1.4498, Train Acc: 0.7141, Val Loss: 1.4905, Val Acc: 0.6720
# Epoch: 41/200, Train Loss: 1.4491, Train Acc: 0.7158, Val Loss: 1.4888, Val Acc: 0.6742
# Epoch: 42/200, Train Loss: 1.4463, Train Acc: 0.7186, Val Loss: 1.4906, Val Acc: 0.6736
# Epoch: 43/200, Train Loss: 1.4463, Train Acc: 0.7183, Val Loss: 1.4881, Val Acc: 0.6744
# Epoch: 44/200, Train Loss: 1.4435, Train Acc: 0.7211, Val Loss: 1.4870, Val Acc: 0.6747
# Epoch: 45/200, Train Loss: 1.4407, Train Acc: 0.7237, Val Loss: 1.4880, Val Acc: 0.6740
# Epoch: 46/200, Train Loss: 1.4408, Train Acc: 0.7243, Val Loss: 1.4849, Val Acc: 0.6778
# Epoch: 47/200, Train Loss: 1.4377, Train Acc: 0.7266, Val Loss: 1.4883, Val Acc: 0.6735
# Epoch: 48/200, Train Loss: 1.4371, Train Acc: 0.7276, Val Loss: 1.4876, Val Acc: 0.6754
# Epoch: 49/200, Train Loss: 1.4350, Train Acc: 0.7295, Val Loss: 1.4861, Val Acc: 0.6781
# Epoch: 50/200, Train Loss: 1.4312, Train Acc: 0.7337, Val Loss: 1.4879, Val Acc: 0.6740
# Epoch: 51/200, Train Loss: 1.4301, Train Acc: 0.7350, Val Loss: 1.4875, Val Acc: 0.6748
# Epoch: 52/200, Train Loss: 1.4283, Train Acc: 0.7361, Val Loss: 1.4869, Val Acc: 0.6761
# Epoch: 53/200, Train Loss: 1.4271, Train Acc: 0.7379, Val Loss: 1.4853, Val Acc: 0.6779
# Epoch: 54/200, Train Loss: 1.4246, Train Acc: 0.7403, Val Loss: 1.4857, Val Acc: 0.6775
# Epoch: 55/200, Train Loss: 1.4228, Train Acc: 0.7427, Val Loss: 1.4845, Val Acc: 0.6782
# Epoch: 56/200, Train Loss: 1.4239, Train Acc: 0.7403, Val Loss: 1.4849, Val Acc: 0.6779
# Epoch: 57/200, Train Loss: 1.4245, Train Acc: 0.7407, Val Loss: 1.4840, Val Acc: 0.6789
# Epoch: 58/200, Train Loss: 1.4217, Train Acc: 0.7437, Val Loss: 1.4844, Val Acc: 0.6789
# Epoch: 59/200, Train Loss: 1.4217, Train Acc: 0.7435, Val Loss: 1.4842, Val Acc: 0.6804
# Epoch: 60/200, Train Loss: 1.4219, Train Acc: 0.7429, Val Loss: 1.4841, Val Acc: 0.6796
# Epoch: 61/200, Train Loss: 1.4196, Train Acc: 0.7454, Val Loss: 1.4835, Val Acc: 0.6791
# Epoch: 62/200, Train Loss: 1.4201, Train Acc: 0.7448, Val Loss: 1.4833, Val Acc: 0.6795
# Epoch: 63/200, Train Loss: 1.4207, Train Acc: 0.7442, Val Loss: 1.4833, Val Acc: 0.6806
# Epoch: 64/200, Train Loss: 1.4208, Train Acc: 0.7438, Val Loss: 1.4831, Val Acc: 0.6794
# Epoch: 65/200, Train Loss: 1.4187, Train Acc: 0.7453, Val Loss: 1.4827, Val Acc: 0.6807
# Epoch: 66/200, Train Loss: 1.4197, Train Acc: 0.7455, Val Loss: 1.4826, Val Acc: 0.6817
# Epoch: 67/200, Train Loss: 1.4180, Train Acc: 0.7471, Val Loss: 1.4821, Val Acc: 0.6813
# Epoch: 68/200, Train Loss: 1.4180, Train Acc: 0.7469, Val Loss: 1.4823, Val Acc: 0.6814
# Epoch: 69/200, Train Loss: 1.4203, Train Acc: 0.7444, Val Loss: 1.4823, Val Acc: 0.6824
# Epoch: 70/200, Train Loss: 1.4194, Train Acc: 0.7456, Val Loss: 1.4821, Val Acc: 0.6805
# Epoch: 71/200, Train Loss: 1.4182, Train Acc: 0.7462, Val Loss: 1.4820, Val Acc: 0.6820
# Epoch: 72/200, Train Loss: 1.4173, Train Acc: 0.7479, Val Loss: 1.4823, Val Acc: 0.6811
# Epoch: 73/200, Train Loss: 1.4195, Train Acc: 0.7453, Val Loss: 1.4830, Val Acc: 0.6805
# Epoch: 74/200, Train Loss: 1.4193, Train Acc: 0.7458, Val Loss: 1.4829, Val Acc: 0.6814
# Epoch: 75/200, Train Loss: 1.4196, Train Acc: 0.7457, Val Loss: 1.4820, Val Acc: 0.6817
# Epoch: 76/200, Train Loss: 1.4166, Train Acc: 0.7486, Val Loss: 1.4826, Val Acc: 0.6818
# Epoch: 77/200, Train Loss: 1.4189, Train Acc: 0.7462, Val Loss: 1.4829, Val Acc: 0.6804
# Epoch: 78/200, Train Loss: 1.4181, Train Acc: 0.7464, Val Loss: 1.4825, Val Acc: 0.6813
# Epoch: 79/200, Train Loss: 1.4197, Train Acc: 0.7455, Val Loss: 1.4831, Val Acc: 0.6807
# Epoch: 80/200, Train Loss: 1.4184, Train Acc: 0.7468, Val Loss: 1.4824, Val Acc: 0.6823
# Epoch: 81/200, Train Loss: 1.4180, Train Acc: 0.7466, Val Loss: 1.4822, Val Acc: 0.6812
# Epoch: 82/200, Train Loss: 1.4188, Train Acc: 0.7456, Val Loss: 1.4828, Val Acc: 0.6808
# Epoch: 83/200, Train Loss: 1.4195, Train Acc: 0.7459, Val Loss: 1.4826, Val Acc: 0.6817
# Epoch: 84/200, Train Loss: 1.4196, Train Acc: 0.7449, Val Loss: 1.4825, Val Acc: 0.6814
# Epoch: 85/200, Train Loss: 1.4190, Train Acc: 0.7464, Val Loss: 1.4826, Val Acc: 0.6807
# Epoch: 86/200, Train Loss: 1.4184, Train Acc: 0.7459, Val Loss: 1.4831, Val Acc: 0.6799
# Epoch: 87/200, Train Loss: 1.4194, Train Acc: 0.7451, Val Loss: 1.4824, Val Acc: 0.6819
# Epoch: 88/200, Train Loss: 1.4176, Train Acc: 0.7469, Val Loss: 1.4826, Val Acc: 0.6811
# Epoch: 89/200, Train Loss: 1.4202, Train Acc: 0.7453, Val Loss: 1.4817, Val Acc: 0.6820
# Epoch: 90/200, Train Loss: 1.4171, Train Acc: 0.7480, Val Loss: 1.4831, Val Acc: 0.6806
# Epoch: 91/200, Train Loss: 1.4193, Train Acc: 0.7460, Val Loss: 1.4828, Val Acc: 0.6813
# Epoch: 92/200, Train Loss: 1.4182, Train Acc: 0.7471, Val Loss: 1.4815, Val Acc: 0.6822
# Epoch: 93/200, Train Loss: 1.4195, Train Acc: 0.7453, Val Loss: 1.4817, Val Acc: 0.6818
# Epoch: 94/200, Train Loss: 1.4188, Train Acc: 0.7463, Val Loss: 1.4828, Val Acc: 0.6812
# Epoch: 95/200, Train Loss: 1.4195, Train Acc: 0.7452, Val Loss: 1.4830, Val Acc: 0.6810
# Epoch: 96/200, Train Loss: 1.4195, Train Acc: 0.7456, Val Loss: 1.4822, Val Acc: 0.6817
# Epoch: 97/200, Train Loss: 1.4191, Train Acc: 0.7459, Val Loss: 1.4830, Val Acc: 0.6801
# Epoch: 98/200, Train Loss: 1.4192, Train Acc: 0.7456, Val Loss: 1.4828, Val Acc: 0.6812
# Epoch: 99/200, Train Loss: 1.4190, Train Acc: 0.7460, Val Loss: 1.4830, Val Acc: 0.6802
# Epoch: 100/200, Train Loss: 1.4212, Train Acc: 0.7443, Val Loss: 1.4827, Val Acc: 0.6807
# Epoch: 101/200, Train Loss: 1.4205, Train Acc: 0.7446, Val Loss: 1.4830, Val Acc: 0.6807
# Epoch: 102/200, Train Loss: 1.4194, Train Acc: 0.7453, Val Loss: 1.4822, Val Acc: 0.6816
# Epoch: 103/200, Train Loss: 1.4188, Train Acc: 0.7456, Val Loss: 1.4821, Val Acc: 0.6823
# Epoch: 104/200, Train Loss: 1.4200, Train Acc: 0.7447, Val Loss: 1.4831, Val Acc: 0.6808
# Epoch: 105/200, Train Loss: 1.4183, Train Acc: 0.7467, Val Loss: 1.4824, Val Acc: 0.6813
# Epoch: 106/200, Train Loss: 1.4182, Train Acc: 0.7467, Val Loss: 1.4831, Val Acc: 0.6796
# Epoch: 107/200, Train Loss: 1.4183, Train Acc: 0.7462, Val Loss: 1.4841, Val Acc: 0.6794
# Epoch: 108/200, Train Loss: 1.4188, Train Acc: 0.7461, Val Loss: 1.4821, Val Acc: 0.6818
# Epoch: 109/200, Train Loss: 1.4178, Train Acc: 0.7473, Val Loss: 1.4830, Val Acc: 0.6800
# Epoch: 110/200, Train Loss: 1.4208, Train Acc: 0.7436, Val Loss: 1.4824, Val Acc: 0.6806
# Epoch: 111/200, Train Loss: 1.4200, Train Acc: 0.7444, Val Loss: 1.4823, Val Acc: 0.6819
# Epoch: 112/200, Train Loss: 1.4189, Train Acc: 0.7461, Val Loss: 1.4830, Val Acc: 0.6814
# Epoch: 113/200, Train Loss: 1.4195, Train Acc: 0.7449, Val Loss: 1.4834, Val Acc: 0.6801
# Epoch: 114/200, Train Loss: 1.4189, Train Acc: 0.7467, Val Loss: 1.4826, Val Acc: 0.6813
# Epoch: 115/200, Train Loss: 1.4198, Train Acc: 0.7450, Val Loss: 1.4827, Val Acc: 0.6816
# Epoch: 116/200, Train Loss: 1.4190, Train Acc: 0.7454, Val Loss: 1.4828, Val Acc: 0.6819
# Epoch: 117/200, Train Loss: 1.4185, Train Acc: 0.7466, Val Loss: 1.4826, Val Acc: 0.6813
# Epoch: 118/200, Train Loss: 1.4193, Train Acc: 0.7446, Val Loss: 1.4822, Val Acc: 0.6820
# Epoch: 119/200, Train Loss: 1.4181, Train Acc: 0.7467, Val Loss: 1.4834, Val Acc: 0.6796
# Epoch: 120/200, Train Loss: 1.4193, Train Acc: 0.7451, Val Loss: 1.4820, Val Acc: 0.6824
# Epoch: 121/200, Train Loss: 1.4199, Train Acc: 0.7450, Val Loss: 1.4816, Val Acc: 0.6827
# Epoch: 122/200, Train Loss: 1.4195, Train Acc: 0.7454, Val Loss: 1.4825, Val Acc: 0.6808
# Epoch: 123/200, Train Loss: 1.4175, Train Acc: 0.7475, Val Loss: 1.4822, Val Acc: 0.6813
# Epoch: 124/200, Train Loss: 1.4201, Train Acc: 0.7451, Val Loss: 1.4819, Val Acc: 0.6825
# Epoch: 125/200, Train Loss: 1.4206, Train Acc: 0.7443, Val Loss: 1.4819, Val Acc: 0.6818
# Epoch: 126/200, Train Loss: 1.4192, Train Acc: 0.7454, Val Loss: 1.4821, Val Acc: 0.6802
# Epoch: 127/200, Train Loss: 1.4188, Train Acc: 0.7452, Val Loss: 1.4822, Val Acc: 0.6822
# Epoch: 128/200, Train Loss: 1.4211, Train Acc: 0.7437, Val Loss: 1.4830, Val Acc: 0.6813
# Epoch: 129/200, Train Loss: 1.4198, Train Acc: 0.7446, Val Loss: 1.4826, Val Acc: 0.6810
# Epoch: 130/200, Train Loss: 1.4179, Train Acc: 0.7473, Val Loss: 1.4827, Val Acc: 0.6805
# Epoch: 131/200, Train Loss: 1.4187, Train Acc: 0.7461, Val Loss: 1.4835, Val Acc: 0.6796
# Epoch: 132/200, Train Loss: 1.4173, Train Acc: 0.7479, Val Loss: 1.4826, Val Acc: 0.6818
# Epoch: 133/200, Train Loss: 1.4205, Train Acc: 0.7444, Val Loss: 1.4828, Val Acc: 0.6798
# Epoch: 134/200, Train Loss: 1.4189, Train Acc: 0.7457, Val Loss: 1.4830, Val Acc: 0.6800
# Epoch: 135/200, Train Loss: 1.4182, Train Acc: 0.7467, Val Loss: 1.4832, Val Acc: 0.6794
# Epoch: 136/200, Train Loss: 1.4179, Train Acc: 0.7468, Val Loss: 1.4829, Val Acc: 0.6812
# Epoch: 137/200, Train Loss: 1.4180, Train Acc: 0.7470, Val Loss: 1.4829, Val Acc: 0.6811
# Epoch: 138/200, Train Loss: 1.4195, Train Acc: 0.7453, Val Loss: 1.4828, Val Acc: 0.6811
# Epoch: 139/200, Train Loss: 1.4188, Train Acc: 0.7462, Val Loss: 1.4833, Val Acc: 0.6807
# Epoch: 140/200, Train Loss: 1.4197, Train Acc: 0.7454, Val Loss: 1.4826, Val Acc: 0.6802
# Epoch: 141/200, Train Loss: 1.4174, Train Acc: 0.7478, Val Loss: 1.4826, Val Acc: 0.6808
# Epoch: 142/200, Train Loss: 1.4194, Train Acc: 0.7454, Val Loss: 1.4818, Val Acc: 0.6824
# Epoch: 143/200, Train Loss: 1.4194, Train Acc: 0.7454, Val Loss: 1.4818, Val Acc: 0.6829
# Epoch: 144/200, Train Loss: 1.4172, Train Acc: 0.7480, Val Loss: 1.4823, Val Acc: 0.6824
# Epoch: 145/200, Train Loss: 1.4209, Train Acc: 0.7434, Val Loss: 1.4818, Val Acc: 0.6827
# Epoch: 146/200, Train Loss: 1.4182, Train Acc: 0.7467, Val Loss: 1.4834, Val Acc: 0.6796
# Epoch: 147/200, Train Loss: 1.4174, Train Acc: 0.7474, Val Loss: 1.4817, Val Acc: 0.6811
# Epoch: 148/200, Train Loss: 1.4183, Train Acc: 0.7469, Val Loss: 1.4837, Val Acc: 0.6799
# Epoch: 149/200, Train Loss: 1.4190, Train Acc: 0.7459, Val Loss: 1.4823, Val Acc: 0.6818
# Epoch: 150/200, Train Loss: 1.4173, Train Acc: 0.7476, Val Loss: 1.4836, Val Acc: 0.6806
# Epoch: 151/200, Train Loss: 1.4195, Train Acc: 0.7449, Val Loss: 1.4825, Val Acc: 0.6814
# Epoch: 152/200, Train Loss: 1.4189, Train Acc: 0.7459, Val Loss: 1.4818, Val Acc: 0.6814
# Epoch: 153/200, Train Loss: 1.4182, Train Acc: 0.7467, Val Loss: 1.4830, Val Acc: 0.6814
# Epoch: 154/200, Train Loss: 1.4181, Train Acc: 0.7467, Val Loss: 1.4817, Val Acc: 0.6816
# Epoch: 155/200, Train Loss: 1.4176, Train Acc: 0.7475, Val Loss: 1.4827, Val Acc: 0.6812
# Epoch: 156/200, Train Loss: 1.4193, Train Acc: 0.7456, Val Loss: 1.4816, Val Acc: 0.6811
# Epoch: 157/200, Train Loss: 1.4187, Train Acc: 0.7460, Val Loss: 1.4822, Val Acc: 0.6814
# Epoch: 158/200, Train Loss: 1.4187, Train Acc: 0.7460, Val Loss: 1.4819, Val Acc: 0.6830
# Epoch: 159/200, Train Loss: 1.4188, Train Acc: 0.7460, Val Loss: 1.4828, Val Acc: 0.6814
# Epoch: 160/200, Train Loss: 1.4187, Train Acc: 0.7460, Val Loss: 1.4823, Val Acc: 0.6820
# Epoch: 161/200, Train Loss: 1.4182, Train Acc: 0.7464, Val Loss: 1.4830, Val Acc: 0.6800
# Epoch: 162/200, Train Loss: 1.4185, Train Acc: 0.7465, Val Loss: 1.4822, Val Acc: 0.6817
# Epoch: 163/200, Train Loss: 1.4182, Train Acc: 0.7467, Val Loss: 1.4824, Val Acc: 0.6822
# Epoch: 164/200, Train Loss: 1.4183, Train Acc: 0.7464, Val Loss: 1.4832, Val Acc: 0.6807
# Epoch: 165/200, Train Loss: 1.4177, Train Acc: 0.7464, Val Loss: 1.4819, Val Acc: 0.6822
# Epoch: 166/200, Train Loss: 1.4182, Train Acc: 0.7471, Val Loss: 1.4835, Val Acc: 0.6807
# Epoch: 167/200, Train Loss: 1.4178, Train Acc: 0.7467, Val Loss: 1.4823, Val Acc: 0.6818
# Epoch: 168/200, Train Loss: 1.4183, Train Acc: 0.7470, Val Loss: 1.4817, Val Acc: 0.6811
# Epoch: 169/200, Train Loss: 1.4188, Train Acc: 0.7456, Val Loss: 1.4824, Val Acc: 0.6823
# Epoch: 170/200, Train Loss: 1.4166, Train Acc: 0.7483, Val Loss: 1.4825, Val Acc: 0.6808
# Epoch: 171/200, Train Loss: 1.4170, Train Acc: 0.7485, Val Loss: 1.4835, Val Acc: 0.6805
# Epoch: 172/200, Train Loss: 1.4191, Train Acc: 0.7456, Val Loss: 1.4824, Val Acc: 0.6811
# Epoch: 173/200, Train Loss: 1.4177, Train Acc: 0.7472, Val Loss: 1.4830, Val Acc: 0.6805
# Epoch: 174/200, Train Loss: 1.4186, Train Acc: 0.7459, Val Loss: 1.4834, Val Acc: 0.6801
# Epoch: 175/200, Train Loss: 1.4178, Train Acc: 0.7472, Val Loss: 1.4824, Val Acc: 0.6817
# Epoch: 176/200, Train Loss: 1.4191, Train Acc: 0.7454, Val Loss: 1.4827, Val Acc: 0.6804
# Epoch: 177/200, Train Loss: 1.4193, Train Acc: 0.7453, Val Loss: 1.4832, Val Acc: 0.6806
# Epoch: 178/200, Train Loss: 1.4198, Train Acc: 0.7448, Val Loss: 1.4837, Val Acc: 0.6801
# Epoch: 179/200, Train Loss: 1.4188, Train Acc: 0.7455, Val Loss: 1.4827, Val Acc: 0.6817
# Epoch: 180/200, Train Loss: 1.4175, Train Acc: 0.7477, Val Loss: 1.4830, Val Acc: 0.6804
# Epoch: 181/200, Train Loss: 1.4199, Train Acc: 0.7450, Val Loss: 1.4830, Val Acc: 0.6801
# Epoch: 182/200, Train Loss: 1.4178, Train Acc: 0.7466, Val Loss: 1.4823, Val Acc: 0.6818
# Epoch: 183/200, Train Loss: 1.4178, Train Acc: 0.7465, Val Loss: 1.4816, Val Acc: 0.6829
# Epoch: 184/200, Train Loss: 1.4189, Train Acc: 0.7459, Val Loss: 1.4827, Val Acc: 0.6805
# Epoch: 185/200, Train Loss: 1.4192, Train Acc: 0.7456, Val Loss: 1.4809, Val Acc: 0.6829
# Epoch: 186/200, Train Loss: 1.4168, Train Acc: 0.7481, Val Loss: 1.4833, Val Acc: 0.6805
# Epoch: 187/200, Train Loss: 1.4195, Train Acc: 0.7455, Val Loss: 1.4822, Val Acc: 0.6810
# Epoch: 188/200, Train Loss: 1.4208, Train Acc: 0.7439, Val Loss: 1.4818, Val Acc: 0.6816
# Epoch: 189/200, Train Loss: 1.4181, Train Acc: 0.7467, Val Loss: 1.4822, Val Acc: 0.6810
# Epoch: 190/200, Train Loss: 1.4199, Train Acc: 0.7457, Val Loss: 1.4823, Val Acc: 0.6822
# Epoch: 191/200, Train Loss: 1.4172, Train Acc: 0.7476, Val Loss: 1.4841, Val Acc: 0.6798
# Epoch: 192/200, Train Loss: 1.4182, Train Acc: 0.7468, Val Loss: 1.4835, Val Acc: 0.6804
# Epoch: 193/200, Train Loss: 1.4180, Train Acc: 0.7473, Val Loss: 1.4823, Val Acc: 0.6806
# Epoch: 194/200, Train Loss: 1.4204, Train Acc: 0.7443, Val Loss: 1.4819, Val Acc: 0.6824
# Epoch: 195/200, Train Loss: 1.4188, Train Acc: 0.7457, Val Loss: 1.4832, Val Acc: 0.6806
# Epoch: 196/200, Train Loss: 1.4177, Train Acc: 0.7475, Val Loss: 1.4829, Val Acc: 0.6807
# Epoch: 197/200, Train Loss: 1.4186, Train Acc: 0.7459, Val Loss: 1.4818, Val Acc: 0.6824
# Epoch: 198/200, Train Loss: 1.4183, Train Acc: 0.7468, Val Loss: 1.4834, Val Acc: 0.6808
# Epoch: 199/200, Train Loss: 1.4177, Train Acc: 0.7470, Val Loss: 1.4826, Val Acc: 0.6813
# Epoch: 200/200, Train Loss: 1.4174, Train Acc: 0.7476, Val Loss: 1.4836, Val Acc: 0.6787

# %%
import torch
import torch.onnx

device = next(model.parameters()).device
dummy_input = torch.randn(1, 3, 128, 128).to(device)

onnx_filename = "FER_Model_Adam.onnx"
torch.onnx.export(model, dummy_input, onnx_filename)

print(f"Model saved as {onnx_filename}")
# Out:
# <ipython-input-11-874faf80d163>:17: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   scaled_attention_logits = qk / torch.sqrt(torch.tensor(dk, dtype=torch.float32, device=qk.device))
# <ipython-input-11-874faf80d163>:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   scaled_attention_logits = qk / torch.sqrt(torch.tensor(dk, dtype=torch.float32, device=qk.device))
# Model saved as FER_Model_Adam.onnx

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

train_acc_list = [float(t) for t in train_acc_list]
val_acc_list = [float(t) for t in val_acc_list]

train_acc_df = pd.DataFrame({'Epoch': range(len(train_acc_list)), 'Accuracy': train_acc_list, 'Type': 'Train'})
val_acc_df = pd.DataFrame({'Epoch': range(len(val_acc_list)), 'Accuracy': val_acc_list, 'Type': 'Validation'})

acc_df = pd.concat([train_acc_df, val_acc_df])

sns.set_style('darkgrid')

plt.figure(figsize=(10, 6))
sns.lineplot(data=acc_df, x='Epoch', y='Accuracy', hue='Type')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Save the graph to a file
plt.savefig('accuracy_graph_Adam.png', dpi=300)

plt.show()
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
train_loss_list = [float(t) for t in train_loss_list]
val_loss_list = [float(t) for t in val_loss_list]

train_loss_list = pd.DataFrame({'Epoch': range(len(train_loss_list)), 'Loss': train_loss_list, 'Type': 'Train'})
val_loss_list = pd.DataFrame({'Epoch': range(len(val_loss_list)), 'Loss': val_loss_list, 'Type': 'Validation'})

acc_df = pd.concat([train_loss_list, val_loss_list])

sns.set_style('darkgrid')

plt.figure(figsize=(10, 6))
sns.lineplot(data=acc_df, x='Epoch', y='Loss', hue='Type')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Save the graph to a file
plt.savefig('loss_graph_Adam.png', dpi=300)

plt.show()

# %%
# define a function to check pytorch version
def check_pytorch_version():
    if torch.__version__ >= '1.6.0':
        return True
    else:
        return False
    
# define a function to check cuda version
def check_cuda_version():
    if torch.cuda.is_available():
        return True
    else:
        return False
    
# define a function to check cudnn version
def check_cudnn_version():
    if check_cuda_version():
        if torch.backends.cudnn.enabled:
            return True
        else:
            return False
    else:
        return False
    
# define a function to check if the system is ready for training
def check_system():
    if check_pytorch_version():
        print('PyTorch version: {}'.format(torch.__version__))
    else:
        print('PyTorch version: {} (update required)'.format(torch.__version__))
        
    if check_cuda_version():
        print('CUDA version: {}'.format(torch.version.cuda))
    else:
        print('CUDA version: {} (install CUDA to enable GPU training)'.format(torch.version.cuda))
        
    if check_cudnn_version():
        print('cuDNN version: {}'.format(torch.backends.cudnn.version()))
    else:
        print('cuDNN version: {} (install cuDNN to enable GPU training)'.format(torch.backends.cudnn.version()))

check_system()
