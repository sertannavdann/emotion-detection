# %% [markdown]
# # Started from here!

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

import cv2
import numpy as np
from PIL import Image
import os

import mediapipe as mp

import heapq
import itertools
from sklearn.decomposition import PCA
# Out:
# /usr/lib/python3/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /usr/lib/python3/dist-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE
#   warn(f"Failed to load image Python extension: {e}")
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
test_dir = 'data/merged/test/'
train_dir = 'data/merged/train/'

classes = os.listdir(train_dir)
test_cls = os.listdir(train_dir)
num_classes = len(classes)

# %%
print(
    f'Number of classes: {num_classes}',
    f'\nClasses: {classes}'
)
# Out:
# Number of classes: 7
# Classes: ['fear', 'angry', 'sad', 'neutral', 'surprise', 'disgust', 'happy']

# %%
print("--------Train--------")
# check the number of images in each class
for cls in classes:
    print(f'{cls}: {len(os.listdir(train_dir + cls))}')

print("\n--------Test--------")
# check the number of images in each class
for cls in classes:
    print(f'{cls}: {len(os.listdir(test_dir + cls))}')
# Out:
# --------Train--------
# fear: 3288
# angry: 3196
# sad: 3852
# neutral: 3948
# surprise: 3456
# disgust: 5674
# happy: 5786
#
# --------Test--------
# fear: 810
# angry: 800
# sad: 979
# neutral: 1018
# surprise: 873
# disgust: 1390
# happy: 1430

# %%
import os
import imghdr
import shutil

def delete_irrelevant_files(directory, classes):
    for cls in classes:
        class_dir = os.path.join(directory, cls)
        with os.scandir(class_dir) as entries:
            for entry in entries:
                # Delete directories
                if entry.is_dir():
                    print(f'Deleting directory: {entry.path}')
                    shutil.rmtree(entry.path)

                # Check if the file is empty and delete it
                elif os.path.getsize(entry.path) == 0:
                    print(f'Deleting empty file: {entry.path}')
                    os.remove(entry.path)

                # Check if the file is not an image and delete it
                elif not imghdr.what(entry.path):
                    print(f'Deleting non-image file: {entry.path}')
                    os.remove(entry.path)

print("--------Train--------")
delete_irrelevant_files(train_dir, classes)

print("\n--------Test--------")
delete_irrelevant_files(test_dir, classes)
# Out:
# --------Train--------
#
# --------Test--------

# %% [markdown]
# # Landmark detection from images and correlation of those landmark positions

# %%
image_size = torch.Size([48, 48, 3])
batch_size = 32

# Compute the total size of the image input
image_input_size = np.prod(image_size) * batch_size * 4. / (1024 ** 2.)
print(f"Image input size: {image_input_size:.2f} MB")
# Out:
# Image input size: 0.84 MB

# %%
class LandmarkDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.data = []
        self.labels = []  # new list to store the label index
        for i, label in enumerate(os.listdir(root_dir)):
            class_dir = os.path.join(root_dir, label)
            for img_name in os.listdir(class_dir):
                img_path = os.path.join(class_dir, img_name)
                image = cv2.imread(img_path)
                self.data.append(image)
                self.labels.append(i)  # add the label index for this image

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image = self.data[idx]
        label = self.labels[idx]  # get the label index for this image

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)

        if self.transform:
            image = self.transform(image)

        return image, label  # return the image and label index

# %%
# Train the model
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.RandomResizedCrop(48, scale=(0.8, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=2),
    transforms.Resize((48, 48)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])


train_dataset = LandmarkDataset(train_dir, transform=transform)
val_dataset = LandmarkDataset(test_dir, transform=transform)
# Out:
# /usr/lib/python3/dist-packages/torchvision/transforms/transforms.py:891: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(

# %%
train_dataloader = DataLoader(train_dataset, batch_size=256, shuffle=True, num_workers=24)
val_dataloader = DataLoader(val_dataset, batch_size=256, shuffle=False, num_workers=24)

# %%
# show shape of the train_dataloader
for i, data in enumerate(train_dataloader):
    print(i, data[0].shape, data[1].shape)
    break

# show shape of the val_dataloader
for i, data in enumerate(val_dataloader):
    print(i, data[0].shape, data[1].shape)
    break

# torch.Size([4, 3, 48, 48]) torch.Size([4])
# torch.Size([4, 3, 48, 48]) torch.Size([4])
# Out:
# 0 torch.Size([256, 3, 48, 48]) torch.Size([256])
# 0 torch.Size([256, 3, 48, 48]) torch.Size([256])

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, input_dim, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.input_dim = input_dim
        self.num_heads = num_heads
        self.head_dim = input_dim // num_heads

        self.query = nn.Linear(input_dim, input_dim)
        self.key = nn.Linear(input_dim, input_dim)
        self.value = nn.Linear(input_dim, input_dim)

        self.fc = nn.Linear(input_dim, input_dim)

    def scaled_dot_product_attention(self, query, key, value):
        qk = torch.matmul(query, key.transpose(-2, -1))
        dk = query.size(-1)
        scaled_attention_logits = qk / torch.sqrt(torch.tensor(dk, dtype=torch.float32))

        attention_weights = F.softmax(scaled_attention_logits, dim=-1)
        output = torch.matmul(attention_weights, value)
        return output, attention_weights

    def split_heads(self, x):
        batch_size = x.size(0)
        x = x.view(batch_size, -1, self.num_heads, self.head_dim)
        return x.transpose(1, 2)

    def forward(self, x):
        batch_size = x.size(0)

        query = self.query(x)
        key = self.key(x)
        value = self.value(x)

        query = self.split_heads(query)
        key = self.split_heads(key)
        value = self.split_heads(value)

        out, attention_weights = self.scaled_dot_product_attention(query, key, value)
        out = out.transpose(1, 2).contiguous().view(batch_size, -1, self.input_dim)

        out = self.fc(out)
        
        return out

# %%
class FacialExpressionDetectionModel(nn.Module):
    def __init__(self, num_classes, num_heads):
        super(FacialExpressionDetectionModel, self).__init__()
        
        # Block-1
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),
            nn.Conv2d(32, 32, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5)
        )

        # Block-2
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 64, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5)
        )

        # Block-3
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.Conv2d(128, 128, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.25)
        )

        # Block-4
        self.conv4 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(256),
            nn.Conv2d(256, 256, kernel_size=3, padding=1, bias=False),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.125)
        )

        # Block-5
        self.fc1 = nn.Sequential(
            nn.Linear(64 * 6 * 6, 128),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(128),
            nn.Dropout(0.25)
        )

        # Attention Layer
        self.attention = MultiHeadAttention(128, num_heads)
        # Change the output size to match the input size of fc2
        self.attention_transform = nn.Linear(128, 64)

        # Block-6
        self.fc2 = nn.Sequential(
            nn.Linear(64, 128),  # Update the input size to 64
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(128),
            nn.Dropout(0.125),
        )

        # Block-7
        self.fc3 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.attention(x)
        x = x.view(x.size(0), -1)  # Flatten the output of the attention layer
        x = self.attention_transform(x)
        #print(x.shape)  # Add this line to print the shape
        x = self.fc2(x)
        x = self.fc3(x)
        return F.softmax(x, dim=1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
num_classes = 7
num_heads = 32
model = FacialExpressionDetectionModel(num_classes, num_heads).to(device)

# %%
with open('model_v2.txt', 'w') as f:
    f.write(str(model))

# %%
import torch.optim as optim
from torch.cuda.amp import GradScaler, autocast
from torch.optim.lr_scheduler import ReduceLROnPlateau

model = FacialExpressionDetectionModel(num_classes, num_heads).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.25)
scaler = GradScaler()

# %%
def train_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    running_corrects = 0

    for data, targets in dataloader:
        data = data.to(device)
        targets = targets.to(device)

        # Use autocast for mixed precision
        with autocast():
            outputs = model(data)
            loss = criterion(outputs, targets)
            _, preds = torch.max(outputs, 1)

        # Scale the loss and perform backpropagation
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        running_loss += loss.item() * data.size(0)
        running_corrects += torch.sum(preds == targets.data)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

# %%
def validate_epoch(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for data, targets in dataloader:
            data, targets = data.to(device), targets.to(device)

            # Use autocast for mixed precision
            with autocast():
                outputs = model(data)
                loss = criterion(outputs, targets)
                _, preds = torch.max(outputs, 1)

            running_loss += loss.item() * data.size(0)
            running_corrects += torch.sum(preds == targets.data)

    epoch_loss = running_loss / len(dataloader.dataset)
    epoch_acc = running_corrects.double() / len(dataloader.dataset)

    return epoch_loss, epoch_acc

# %%
print(device)
# Out:
# cuda

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
import matplotlib.pyplot as plt

# create empty lists to store loss and accuracy for each epoch
train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

num_epochs = 200
for epoch in range(num_epochs):
    
    train_loss, train_acc = train_epoch(model, train_dataloader, criterion, optimizer, device)
    val_loss, val_acc = validate_epoch(model, val_dataloader, criterion, device)
    scheduler.step(val_loss)
    
    # append the loss and accuracy to the lists
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)


    print(f"Epoch: {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
# Out:
# Epoch: 1/200, Train Loss: 1.7915, Train Acc: 0.3679, Val Loss: 1.7810, Val Acc: 0.3749
# Epoch: 2/200, Train Loss: 1.7592, Train Acc: 0.3969, Val Loss: 1.7572, Val Acc: 0.3995
# Epoch: 3/200, Train Loss: 1.7372, Train Acc: 0.4196, Val Loss: 1.7442, Val Acc: 0.4112
# Epoch: 4/200, Train Loss: 1.7218, Train Acc: 0.4336, Val Loss: 1.6979, Val Acc: 0.4570
# Epoch: 5/200, Train Loss: 1.6957, Train Acc: 0.4608, Val Loss: 1.6957, Val Acc: 0.4588
# Epoch: 6/200, Train Loss: 1.6873, Train Acc: 0.4681, Val Loss: 1.6893, Val Acc: 0.4664
# Epoch: 7/200, Train Loss: 1.6787, Train Acc: 0.4765, Val Loss: 1.6638, Val Acc: 0.4914
# Epoch: 8/200, Train Loss: 1.6643, Train Acc: 0.4923, Val Loss: 1.6656, Val Acc: 0.4899
# Epoch: 9/200, Train Loss: 1.6561, Train Acc: 0.4998, Val Loss: 1.6555, Val Acc: 0.4996
# Epoch: 10/200, Train Loss: 1.6543, Train Acc: 0.5025, Val Loss: 1.6536, Val Acc: 0.5047
# Epoch: 11/200, Train Loss: 1.6493, Train Acc: 0.5072, Val Loss: 1.6598, Val Acc: 0.5005
# Epoch: 12/200, Train Loss: 1.6408, Train Acc: 0.5178, Val Loss: 1.6407, Val Acc: 0.5173
# Epoch: 13/200, Train Loss: 1.6352, Train Acc: 0.5222, Val Loss: 1.6326, Val Acc: 0.5249
# Epoch: 14/200, Train Loss: 1.6342, Train Acc: 0.5230, Val Loss: 1.6499, Val Acc: 0.5058
# Epoch: 15/200, Train Loss: 1.6332, Train Acc: 0.5259, Val Loss: 1.6319, Val Acc: 0.5232
# Epoch: 16/200, Train Loss: 1.6294, Train Acc: 0.5297, Val Loss: 1.6494, Val Acc: 0.5042
# Epoch: 17/200, Train Loss: 1.6255, Train Acc: 0.5355, Val Loss: 1.6179, Val Acc: 0.5382
# Epoch: 18/200, Train Loss: 1.6246, Train Acc: 0.5338, Val Loss: 1.6108, Val Acc: 0.5466
# Epoch: 19/200, Train Loss: 1.6158, Train Acc: 0.5423, Val Loss: 1.6101, Val Acc: 0.5493
# Epoch: 20/200, Train Loss: 1.6105, Train Acc: 0.5468, Val Loss: 1.6190, Val Acc: 0.5384
# Epoch: 21/200, Train Loss: 1.6115, Train Acc: 0.5474, Val Loss: 1.6030, Val Acc: 0.5518
# Epoch: 22/200, Train Loss: 1.6078, Train Acc: 0.5509, Val Loss: 1.6032, Val Acc: 0.5541
# Epoch: 23/200, Train Loss: 1.6033, Train Acc: 0.5561, Val Loss: 1.6079, Val Acc: 0.5504
# Epoch: 24/200, Train Loss: 1.6076, Train Acc: 0.5518, Val Loss: 1.6032, Val Acc: 0.5536
# Epoch: 25/200, Train Loss: 1.5979, Train Acc: 0.5625, Val Loss: 1.6012, Val Acc: 0.5559
# Epoch: 26/200, Train Loss: 1.6066, Train Acc: 0.5531, Val Loss: 1.6074, Val Acc: 0.5508
# Epoch: 27/200, Train Loss: 1.6014, Train Acc: 0.5570, Val Loss: 1.5963, Val Acc: 0.5604
# Epoch: 28/200, Train Loss: 1.6016, Train Acc: 0.5570, Val Loss: 1.6005, Val Acc: 0.5590
# Epoch: 50/200, Train Loss: 1.5702, Train Acc: 0.5905, Val Loss: 1.5720, Val Acc: 0.5878
# Epoch: 51/200, Train Loss: 1.5689, Train Acc: 0.5914, Val Loss: 1.5737, Val Acc: 0.5855
# Epoch: 52/200, Train Loss: 1.5684, Train Acc: 0.5933, Val Loss: 1.5746, Val Acc: 0.5842
# Epoch: 53/200, Train Loss: 1.5704, Train Acc: 0.5898, Val Loss: 1.5727, Val Acc: 0.5870
# Epoch: 54/200, Train Loss: 1.5704, Train Acc: 0.5891, Val Loss: 1.5739, Val Acc: 0.5842
# Epoch: 55/200, Train Loss: 1.5682, Train Acc: 0.5925, Val Loss: 1.5744, Val Acc: 0.5836
# Epoch: 56/200, Train Loss: 1.5701, Train Acc: 0.5899, Val Loss: 1.5703, Val Acc: 0.5889
# Epoch: 57/200, Train Loss: 1.5677, Train Acc: 0.5920, Val Loss: 1.5723, Val Acc: 0.5870
# Epoch: 58/200, Train Loss: 1.5669, Train Acc: 0.5937, Val Loss: 1.5742, Val Acc: 0.5847
# Epoch: 59/200, Train Loss: 1.5703, Train Acc: 0.5901, Val Loss: 1.5689, Val Acc: 0.5912
# Epoch: 60/200, Train Loss: 1.5682, Train Acc: 0.5922, Val Loss: 1.5745, Val Acc: 0.5821
# Epoch: 61/200, Train Loss: 1.5689, Train Acc: 0.5917, Val Loss: 1.5717, Val Acc: 0.5892
# Epoch: 62/200, Train Loss: 1.5694, Train Acc: 0.5906, Val Loss: 1.5678, Val Acc: 0.5921
# Epoch: 63/200, Train Loss: 1.5680, Train Acc: 0.5915, Val Loss: 1.5723, Val Acc: 0.5886
# Epoch: 64/200, Train Loss: 1.5681, Train Acc: 0.5923, Val Loss: 1.5732, Val Acc: 0.5858
# Epoch: 65/200, Train Loss: 1.5687, Train Acc: 0.5914, Val Loss: 1.5727, Val Acc: 0.5874
# Epoch: 66/200, Train Loss: 1.5710, Train Acc: 0.5896, Val Loss: 1.5705, Val Acc: 0.5871
# Epoch: 67/200, Train Loss: 1.5694, Train Acc: 0.5903, Val Loss: 1.5707, Val Acc: 0.5878
# Epoch: 68/200, Train Loss: 1.5690, Train Acc: 0.5903, Val Loss: 1.5705, Val Acc: 0.5878
# Epoch: 69/200, Train Loss: 1.5681, Train Acc: 0.5918, Val Loss: 1.5725, Val Acc: 0.5844
# Epoch: 70/200, Train Loss: 1.5688, Train Acc: 0.5916, Val Loss: 1.5743, Val Acc: 0.5852
# Epoch: 71/200, Train Loss: 1.5677, Train Acc: 0.5925, Val Loss: 1.5703, Val Acc: 0.5901
# Epoch: 72/200, Train Loss: 1.5679, Train Acc: 0.5933, Val Loss: 1.5729, Val Acc: 0.5851
# Epoch: 73/200, Train Loss: 1.5674, Train Acc: 0.5930, Val Loss: 1.5731, Val Acc: 0.5847
# Epoch: 74/200, Train Loss: 1.5681, Train Acc: 0.5929, Val Loss: 1.5711, Val Acc: 0.5875
# Epoch: 75/200, Train Loss: 1.5704, Train Acc: 0.5892, Val Loss: 1.5767, Val Acc: 0.5786
# Epoch: 76/200, Train Loss: 1.5696, Train Acc: 0.5911, Val Loss: 1.5733, Val Acc: 0.5849
# Epoch: 77/200, Train Loss: 1.5702, Train Acc: 0.5896, Val Loss: 1.5728, Val Acc: 0.5845
# Epoch: 78/200, Train Loss: 1.5707, Train Acc: 0.5886, Val Loss: 1.5725, Val Acc: 0.5860
# Epoch: 79/200, Train Loss: 1.5693, Train Acc: 0.5901, Val Loss: 1.5716, Val Acc: 0.5877
# Epoch: 80/200, Train Loss: 1.5691, Train Acc: 0.5916, Val Loss: 1.5730, Val Acc: 0.5863
# Epoch: 81/200, Train Loss: 1.5679, Train Acc: 0.5908, Val Loss: 1.5705, Val Acc: 0.5882
# Epoch: 82/200, Train Loss: 1.5709, Train Acc: 0.5885, Val Loss: 1.5737, Val Acc: 0.5852
# Epoch: 83/200, Train Loss: 1.5700, Train Acc: 0.5901, Val Loss: 1.5722, Val Acc: 0.5873
# Epoch: 84/200, Train Loss: 1.5705, Train Acc: 0.5899, Val Loss: 1.5728, Val Acc: 0.5856
# Epoch: 85/200, Train Loss: 1.5685, Train Acc: 0.5920, Val Loss: 1.5739, Val Acc: 0.5845
# Epoch: 86/200, Train Loss: 1.5688, Train Acc: 0.5920, Val Loss: 1.5711, Val Acc: 0.5860
# Epoch: 87/200, Train Loss: 1.5695, Train Acc: 0.5909, Val Loss: 1.5699, Val Acc: 0.5875
# Epoch: 88/200, Train Loss: 1.5720, Train Acc: 0.5883, Val Loss: 1.5710, Val Acc: 0.5874
# Epoch: 89/200, Train Loss: 1.5697, Train Acc: 0.5904, Val Loss: 1.5719, Val Acc: 0.5862
# Epoch: 90/200, Train Loss: 1.5689, Train Acc: 0.5915, Val Loss: 1.5706, Val Acc: 0.5879
# Epoch: 91/200, Train Loss: 1.5696, Train Acc: 0.5894, Val Loss: 1.5725, Val Acc: 0.5881
# Epoch: 92/200, Train Loss: 1.5675, Train Acc: 0.5935, Val Loss: 1.5773, Val Acc: 0.5815
# Epoch: 93/200, Train Loss: 1.5685, Train Acc: 0.5910, Val Loss: 1.5714, Val Acc: 0.5885
# Epoch: 94/200, Train Loss: 1.5704, Train Acc: 0.5893, Val Loss: 1.5729, Val Acc: 0.5870
# Epoch: 95/200, Train Loss: 1.5693, Train Acc: 0.5905, Val Loss: 1.5703, Val Acc: 0.5893
# Epoch: 96/200, Train Loss: 1.5708, Train Acc: 0.5893, Val Loss: 1.5751, Val Acc: 0.5818
# Epoch: 97/200, Train Loss: 1.5676, Train Acc: 0.5928, Val Loss: 1.5708, Val Acc: 0.5864
# Epoch: 98/200, Train Loss: 1.5696, Train Acc: 0.5908, Val Loss: 1.5700, Val Acc: 0.5897
# Epoch: 99/200, Train Loss: 1.5691, Train Acc: 0.5914, Val Loss: 1.5782, Val Acc: 0.5801
# Epoch: 100/200, Train Loss: 1.5717, Train Acc: 0.5873, Val Loss: 1.5697, Val Acc: 0.5895
# Epoch: 101/200, Train Loss: 1.5690, Train Acc: 0.5904, Val Loss: 1.5707, Val Acc: 0.5886
# Epoch: 102/200, Train Loss: 1.5697, Train Acc: 0.5903, Val Loss: 1.5742, Val Acc: 0.5844
# Epoch: 103/200, Train Loss: 1.5691, Train Acc: 0.5897, Val Loss: 1.5685, Val Acc: 0.5911
# Epoch: 104/200, Train Loss: 1.5678, Train Acc: 0.5926, Val Loss: 1.5722, Val Acc: 0.5859
# Epoch: 105/200, Train Loss: 1.5707, Train Acc: 0.5890, Val Loss: 1.5734, Val Acc: 0.5852
# Epoch: 106/200, Train Loss: 1.5702, Train Acc: 0.5902, Val Loss: 1.5721, Val Acc: 0.5866
# Epoch: 107/200, Train Loss: 1.5715, Train Acc: 0.5887, Val Loss: 1.5739, Val Acc: 0.5834
# Epoch: 108/200, Train Loss: 1.5700, Train Acc: 0.5890, Val Loss: 1.5728, Val Acc: 0.5852
# Epoch: 109/200, Train Loss: 1.5689, Train Acc: 0.5914, Val Loss: 1.5743, Val Acc: 0.5837
# Epoch: 110/200, Train Loss: 1.5697, Train Acc: 0.5899, Val Loss: 1.5738, Val Acc: 0.5822
# Epoch: 111/200, Train Loss: 1.5693, Train Acc: 0.5917, Val Loss: 1.5714, Val Acc: 0.5866
# Epoch: 112/200, Train Loss: 1.5690, Train Acc: 0.5910, Val Loss: 1.5712, Val Acc: 0.5878
# Epoch: 113/200, Train Loss: 1.5711, Train Acc: 0.5884, Val Loss: 1.5734, Val Acc: 0.5853
# Epoch: 114/200, Train Loss: 1.5692, Train Acc: 0.5914, Val Loss: 1.5694, Val Acc: 0.5863
# Epoch: 115/200, Train Loss: 1.5709, Train Acc: 0.5903, Val Loss: 1.5732, Val Acc: 0.5874
# Epoch: 116/200, Train Loss: 1.5682, Train Acc: 0.5916, Val Loss: 1.5712, Val Acc: 0.5886
# Epoch: 117/200, Train Loss: 1.5682, Train Acc: 0.5921, Val Loss: 1.5696, Val Acc: 0.5897
# Epoch: 118/200, Train Loss: 1.5713, Train Acc: 0.5892, Val Loss: 1.5732, Val Acc: 0.5852
# Epoch: 119/200, Train Loss: 1.5687, Train Acc: 0.5915, Val Loss: 1.5705, Val Acc: 0.5886
# Epoch: 120/200, Train Loss: 1.5695, Train Acc: 0.5905, Val Loss: 1.5728, Val Acc: 0.5853
# Epoch: 121/200, Train Loss: 1.5675, Train Acc: 0.5934, Val Loss: 1.5754, Val Acc: 0.5848
# Epoch: 122/200, Train Loss: 1.5701, Train Acc: 0.5896, Val Loss: 1.5735, Val Acc: 0.5832
# Epoch: 123/200, Train Loss: 1.5721, Train Acc: 0.5873, Val Loss: 1.5727, Val Acc: 0.5840
# Epoch: 124/200, Train Loss: 1.5688, Train Acc: 0.5916, Val Loss: 1.5727, Val Acc: 0.5864
# Epoch: 125/200, Train Loss: 1.5684, Train Acc: 0.5917, Val Loss: 1.5724, Val Acc: 0.5853
# Epoch: 126/200, Train Loss: 1.5698, Train Acc: 0.5894, Val Loss: 1.5743, Val Acc: 0.5822
# Epoch: 127/200, Train Loss: 1.5701, Train Acc: 0.5895, Val Loss: 1.5739, Val Acc: 0.5823
# Epoch: 128/200, Train Loss: 1.5682, Train Acc: 0.5926, Val Loss: 1.5726, Val Acc: 0.5868
# Epoch: 129/200, Train Loss: 1.5702, Train Acc: 0.5907, Val Loss: 1.5699, Val Acc: 0.5884
# Epoch: 130/200, Train Loss: 1.5683, Train Acc: 0.5915, Val Loss: 1.5726, Val Acc: 0.5855
# Epoch: 131/200, Train Loss: 1.5688, Train Acc: 0.5928, Val Loss: 1.5750, Val Acc: 0.5811
# Epoch: 132/200, Train Loss: 1.5704, Train Acc: 0.5889, Val Loss: 1.5722, Val Acc: 0.5868
# Epoch: 133/200, Train Loss: 1.5700, Train Acc: 0.5896, Val Loss: 1.5702, Val Acc: 0.5855
# Epoch: 134/200, Train Loss: 1.5713, Train Acc: 0.5889, Val Loss: 1.5684, Val Acc: 0.5911
# Epoch: 135/200, Train Loss: 1.5708, Train Acc: 0.5897, Val Loss: 1.5707, Val Acc: 0.5878
# Epoch: 136/200, Train Loss: 1.5701, Train Acc: 0.5903, Val Loss: 1.5719, Val Acc: 0.5855
# Epoch: 137/200, Train Loss: 1.5694, Train Acc: 0.5912, Val Loss: 1.5735, Val Acc: 0.5852
# Epoch: 138/200, Train Loss: 1.5686, Train Acc: 0.5916, Val Loss: 1.5675, Val Acc: 0.5910
# Epoch: 139/200, Train Loss: 1.5706, Train Acc: 0.5908, Val Loss: 1.5720, Val Acc: 0.5874
# Epoch: 140/200, Train Loss: 1.5701, Train Acc: 0.5887, Val Loss: 1.5743, Val Acc: 0.5825
# Epoch: 141/200, Train Loss: 1.5684, Train Acc: 0.5921, Val Loss: 1.5715, Val Acc: 0.5852
# Epoch: 142/200, Train Loss: 1.5695, Train Acc: 0.5912, Val Loss: 1.5709, Val Acc: 0.5892
# Epoch: 143/200, Train Loss: 1.5695, Train Acc: 0.5907, Val Loss: 1.5690, Val Acc: 0.5895
# Epoch: 144/200, Train Loss: 1.5681, Train Acc: 0.5926, Val Loss: 1.5747, Val Acc: 0.5862
# Epoch: 145/200, Train Loss: 1.5673, Train Acc: 0.5919, Val Loss: 1.5714, Val Acc: 0.5882
# Epoch: 146/200, Train Loss: 1.5713, Train Acc: 0.5895, Val Loss: 1.5723, Val Acc: 0.5851
# Epoch: 147/200, Train Loss: 1.5681, Train Acc: 0.5932, Val Loss: 1.5733, Val Acc: 0.5866
# Epoch: 148/200, Train Loss: 1.5677, Train Acc: 0.5924, Val Loss: 1.5754, Val Acc: 0.5821
# Epoch: 149/200, Train Loss: 1.5700, Train Acc: 0.5900, Val Loss: 1.5701, Val Acc: 0.5873
# Epoch: 150/200, Train Loss: 1.5730, Train Acc: 0.5865, Val Loss: 1.5711, Val Acc: 0.5895
# Epoch: 151/200, Train Loss: 1.5715, Train Acc: 0.5892, Val Loss: 1.5725, Val Acc: 0.5844
# Epoch: 152/200, Train Loss: 1.5676, Train Acc: 0.5927, Val Loss: 1.5658, Val Acc: 0.5937
# Epoch: 153/200, Train Loss: 1.5679, Train Acc: 0.5926, Val Loss: 1.5691, Val Acc: 0.5915
# Epoch: 154/200, Train Loss: 1.5703, Train Acc: 0.5901, Val Loss: 1.5734, Val Acc: 0.5859
# Epoch: 155/200, Train Loss: 1.5687, Train Acc: 0.5914, Val Loss: 1.5751, Val Acc: 0.5815
# Epoch: 156/200, Train Loss: 1.5655, Train Acc: 0.5953, Val Loss: 1.5741, Val Acc: 0.5825
# Epoch: 157/200, Train Loss: 1.5694, Train Acc: 0.5917, Val Loss: 1.5721, Val Acc: 0.5870
# Epoch: 158/200, Train Loss: 1.5697, Train Acc: 0.5901, Val Loss: 1.5723, Val Acc: 0.5855
# Epoch: 159/200, Train Loss: 1.5709, Train Acc: 0.5889, Val Loss: 1.5741, Val Acc: 0.5845
# Epoch: 160/200, Train Loss: 1.5697, Train Acc: 0.5903, Val Loss: 1.5679, Val Acc: 0.5926
# Epoch: 161/200, Train Loss: 1.5702, Train Acc: 0.5884, Val Loss: 1.5732, Val Acc: 0.5853
# Epoch: 162/200, Train Loss: 1.5689, Train Acc: 0.5917, Val Loss: 1.5714, Val Acc: 0.5873
# Epoch: 163/200, Train Loss: 1.5699, Train Acc: 0.5901, Val Loss: 1.5731, Val Acc: 0.5833
# Epoch: 164/200, Train Loss: 1.5672, Train Acc: 0.5940, Val Loss: 1.5694, Val Acc: 0.5879
# Epoch: 165/200, Train Loss: 1.5686, Train Acc: 0.5923, Val Loss: 1.5726, Val Acc: 0.5852
# Epoch: 166/200, Train Loss: 1.5719, Train Acc: 0.5874, Val Loss: 1.5774, Val Acc: 0.5796
# Epoch: 167/200, Train Loss: 1.5707, Train Acc: 0.5888, Val Loss: 1.5721, Val Acc: 0.5837
# Epoch: 168/200, Train Loss: 1.5696, Train Acc: 0.5896, Val Loss: 1.5730, Val Acc: 0.5862
# Epoch: 169/200, Train Loss: 1.5722, Train Acc: 0.5877, Val Loss: 1.5666, Val Acc: 0.5932
# Epoch: 170/200, Train Loss: 1.5683, Train Acc: 0.5925, Val Loss: 1.5724, Val Acc: 0.5874
# Epoch: 171/200, Train Loss: 1.5693, Train Acc: 0.5907, Val Loss: 1.5710, Val Acc: 0.5858
# Epoch: 172/200, Train Loss: 1.5700, Train Acc: 0.5900, Val Loss: 1.5728, Val Acc: 0.5870
# Epoch: 173/200, Train Loss: 1.5708, Train Acc: 0.5888, Val Loss: 1.5699, Val Acc: 0.5892
# Epoch: 174/200, Train Loss: 1.5671, Train Acc: 0.5940, Val Loss: 1.5743, Val Acc: 0.5840
# Epoch: 175/200, Train Loss: 1.5707, Train Acc: 0.5897, Val Loss: 1.5731, Val Acc: 0.5858
# Epoch: 176/200, Train Loss: 1.5699, Train Acc: 0.5909, Val Loss: 1.5699, Val Acc: 0.5890
# Epoch: 177/200, Train Loss: 1.5695, Train Acc: 0.5903, Val Loss: 1.5686, Val Acc: 0.5899
# Epoch: 178/200, Train Loss: 1.5697, Train Acc: 0.5913, Val Loss: 1.5710, Val Acc: 0.5897
# Epoch: 179/200, Train Loss: 1.5693, Train Acc: 0.5902, Val Loss: 1.5743, Val Acc: 0.5837
# Epoch: 180/200, Train Loss: 1.5701, Train Acc: 0.5897, Val Loss: 1.5666, Val Acc: 0.5907
# Epoch: 181/200, Train Loss: 1.5689, Train Acc: 0.5905, Val Loss: 1.5690, Val Acc: 0.5886
# Epoch: 182/200, Train Loss: 1.5703, Train Acc: 0.5905, Val Loss: 1.5730, Val Acc: 0.5848
# Epoch: 183/200, Train Loss: 1.5682, Train Acc: 0.5928, Val Loss: 1.5700, Val Acc: 0.5893
# Epoch: 184/200, Train Loss: 1.5709, Train Acc: 0.5880, Val Loss: 1.5675, Val Acc: 0.5915
# Epoch: 185/200, Train Loss: 1.5699, Train Acc: 0.5893, Val Loss: 1.5698, Val Acc: 0.5875
# Epoch: 186/200, Train Loss: 1.5687, Train Acc: 0.5908, Val Loss: 1.5732, Val Acc: 0.5852
# Epoch: 187/200, Train Loss: 1.5674, Train Acc: 0.5927, Val Loss: 1.5703, Val Acc: 0.5858
# Epoch: 188/200, Train Loss: 1.5709, Train Acc: 0.5898, Val Loss: 1.5713, Val Acc: 0.5875
# Epoch: 189/200, Train Loss: 1.5700, Train Acc: 0.5901, Val Loss: 1.5722, Val Acc: 0.5859
# Epoch: 190/200, Train Loss: 1.5716, Train Acc: 0.5870, Val Loss: 1.5681, Val Acc: 0.5911
# Epoch: 191/200, Train Loss: 1.5725, Train Acc: 0.5870, Val Loss: 1.5712, Val Acc: 0.5893
# Epoch: 192/200, Train Loss: 1.5695, Train Acc: 0.5908, Val Loss: 1.5689, Val Acc: 0.5903
# Epoch: 193/200, Train Loss: 1.5671, Train Acc: 0.5932, Val Loss: 1.5714, Val Acc: 0.5856
# Epoch: 194/200, Train Loss: 1.5705, Train Acc: 0.5894, Val Loss: 1.5671, Val Acc: 0.5923

# %%
model2 = FacialExpressionDetectionModel(num_classes, num_heads).to(device)

optimizer = optim.RMSprop(model.parameters(), lr=0.001, weight_decay=0.0001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# %%
import matplotlib.pyplot as plt

# create empty lists to store loss and accuracy for each epoch
train_loss_list2 = []
train_acc_list2 = []
val_loss_list2 = []
val_acc_list2 = []

num_epochs = 60
for epoch in range(num_epochs):
    
    train_loss, train_acc = train_epoch(model2, train_dataloader, criterion, optimizer, device)
    val_loss, val_acc = validate_epoch(model2, val_dataloader, criterion, device)
    scheduler.step(val_loss)
    
    # append the loss and accuracy to the lists
    train_loss_list2.append(train_loss)
    train_acc_list2.append(train_acc)
    val_loss_list2.append(val_loss)
    val_acc_list2.append(val_acc)


    print(f"Epoch: {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

# %%
model3 = FacialExpressionDetectionModel(num_classes, num_heads).to(device)

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0001)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50, eta_min=0)

# %%
import matplotlib.pyplot as plt

# create empty lists to store loss and accuracy for each epoch
train_loss_list3 = []
train_acc_list3 = []
val_loss_list3 = []
val_acc_list3 = []

num_epochs = 60
for epoch in range(num_epochs):
    
    train_loss, train_acc = train_epoch(model3, train_dataloader, criterion, optimizer, device)
    val_loss, val_acc = validate_epoch(model3, val_dataloader, criterion, device)
    scheduler.step(val_loss)
    
    # append the loss and accuracy to the lists
    train_loss_list3.append(train_loss)
    train_acc_list3.append(train_acc)
    val_loss_list3.append(val_loss)
    val_acc_list3.append(val_acc)


    print(f"Epoch: {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

train_acc_np = [t.cpu().numpy() for t in train_acc_list]
val_acc_np = [t.cpu().numpy() for t in val_acc_list]

sns.set_style('darkgrid')

plt.figure(figsize=(10, 6))
sns.lineplot(data=train_acc_np, label='Train')
sns.lineplot(data=val_acc_np, label='Validation')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# convert lists to dataframes
train_acc_df = pd.DataFrame({'accuracy': train_acc_list})
val_acc_df = pd.DataFrame({'accuracy': val_acc_list})

# %%
# define a function to check pytorch version
def check_pytorch_version():
    if torch.__version__ >= '1.6.0':
        return True
    else:
        return False
    
# define a function to check cuda version
def check_cuda_version():
    if torch.cuda.is_available():
        return True
    else:
        return False
    
# define a function to check cudnn version
def check_cudnn_version():
    if check_cuda_version():
        if torch.backends.cudnn.enabled:
            return True
        else:
            return False
    else:
        return False
    
# define a function to check if the system is ready for training
def check_system():
    if check_pytorch_version():
        print('PyTorch version: {}'.format(torch.__version__))
    else:
        print('PyTorch version: {} (update required)'.format(torch.__version__))
        
    if check_cuda_version():
        print('CUDA version: {}'.format(torch.version.cuda))
    else:
        print('CUDA version: {} (install CUDA to enable GPU training)'.format(torch.version.cuda))
        
    if check_cudnn_version():
        print('cuDNN version: {}'.format(torch.backends.cudnn.version()))
    else:
        print('cuDNN version: {} (install cuDNN to enable GPU training)'.format(torch.backends.cudnn.version()))

check_system()
